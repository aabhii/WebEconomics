# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
% matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import scipy.stats as stats

# %%
df = pd.read_csv("./train.csv")

# %%
df.head()
# Out:
#    click  weekday  hour                                     bidid  \
# 0      0        5    22  b7bea80521fdecd95d2d761a38c91c3f09618066
# 1      0        1    20  4f51205475678f5a124bc76b2c54163bf8eaa7eb
# 2      0        3    13  b604e3fd054a658ab7ced4285ebf2ef54d2bd890
# 3      0        6    23  0348beeae93e561584c3b50fc9e7746a33048ad7
# 4      0        5     6  268149c1789bce2bc9798ffd97ec431219bafeb3
#
#                                      userid       useragent             IP  \
# 0  2e880fb7d690cf7377b2e42e701728e3f3c0e4c1      windows_ie   125.37.175.*
# 1  3a1fe01360ff8100e7d006b83b77a3e4c01d928c  windows_chrome    171.36.92.*
# 2  801d18a056b6fe6b06a794aef17fb0d6daff2414      windows_ie    59.46.106.*
# 3  0d6eaf2259699990e38a1fc5116f112070b9ecdc      windows_ie  114.250.226.*
# 4  a239d9bb642460d974ba67f85e63b8d3e214da0e      windows_ie   183.63.192.*
#
#    region  city adexchange           ...            slotheight slotvisibility  \
# ...

# %%
df['adexchange'].head()
# Out:
# 0    2
# 1    1
# 2    2
# 3    1
# 4    2
# Name: adexchange, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430981 entries, 0 to 2430980
# Data columns (total 25 columns):
# click             int64
# weekday           int64
# hour              int64
# bidid             object
# userid            object
# useragent         object
# IP                object
# region            int64
# city              int64
# adexchange        object
# domain            object
# url               object
# urlid             object
# slotid            object
# slotwidth         int64
# slotheight        int64
# slotvisibility    object
# slotformat        object
# slotprice         int64
# creative          object
# bidprice          int64
# payprice          int64
# keypage           object
# advertiser        int64
# usertag           object
# dtypes: int64(11), object(14)
# memory usage: 463.7+ MB

# %%
cost_2259 = 0 
df_2259 = df.loc[df['advertiser'] == 2259]
for index, row in df_2259.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_2259 += row['payprice']
print (cost_2259)
# Out:
# 12411390

# %%
cost_1458 = 0 
df_1458 = df.loc[df['advertiser'] == 1458]
for index, row in df_1458.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_1458 += row['payprice']
print (cost_1458)
# Out:
# 33732036

# %%
cost_2821 = 0 
df_2821 = df.loc[df['advertiser'] == 2821]
for index, row in df_2821.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_2821 += row['payprice']
print (cost_2821)
# Out:
# 18799210

# %%
cost_3386 = 0 
df_3386 = df.loc[df['advertiser'] == 3386]
for index, row in df_3386.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_3386 += row['payprice']
print (cost_3386)
# Out:
# 34736523

# %%
cost_3358 = 0 
df_3358 = df.loc[df['advertiser'] == 3358]
for index, row in df_3358.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_3358 += row['payprice']
print (cost_3358)
# Out:
# 22308705

# %%
cost_3476 = 0 
df_3476 = df.loc[df['advertiser'] == 3476]
for index, row in df_3476.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_3476 += row['payprice']
print (cost_3476)
# Out:
# 23878311

# %%
cost_2261 = 0 
df_2261 = df.loc[df['advertiser'] == 2261]
for index, row in df_2261.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_2261 += row['payprice']
print (cost_2261)
# Out:
# 9857123

# %%
cost_2997 = 0 
df_2997 = df.loc[df['advertiser'] == 2997]
for index, row in df_2997.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_2997 += row['payprice']
print (cost_2997)
# Out:
# 3126220

# %%
cost_3427 = 0 
df_3427 = df.loc[df['advertiser'] == 3427]
for index, row in df_3427.iterrows():
    if (row['bidprice'] > row['payprice']):        
        cost_3427 += row['payprice']
print (cost_3427)
# Out:
# 30386516

# %%
# group df by advertiser to get the number of impressions by advertiser

# number of unique advertisers in df
len(df['advertiser'].unique())

# find number of impressions by advertiser
advertiser = pd.DataFrame()
advertiser['num_impressions'] = df.groupby('advertiser')['click'].count()
advertiser['num_clicks'] = df.groupby('advertiser')['click'].sum()
cost = np.array([cost_1458,cost_2259,cost_2261,cost_2821,cost_2997,cost_3358,cost_3386,cost_3427,cost_3476])
advertiser['cost'] = cost

# %%
#CTR = Click-through rate (CTR) is the 
#ratio of users who click on a specific link to the number of total users 
#who view a page, email, or advertisement.

advertiser['CTR'] = (advertiser['num_clicks']/advertiser['num_impressions'])*100
advertiser
# Out:
#             num_impressions  num_clicks      cost       CTR
# advertiser
# 1458                 492353         385  33732036  0.078196
# 2259                 133673          43  12411390  0.032168
# 2261                 110122          36   9857123  0.032691
# 2821                 211366         131  18799210  0.061978
# 2997                  49829         217   3126220  0.435489
# 3358                 264956         202  22308705  0.076239
# 3386                 455041         320  34736523  0.070323
# 3427                 402806         272  30386516  0.067526
# 3476                 310835         187  23878311  0.060161

# %% [markdown]
# # CPM
# Cost per thousand (CPM) is a marketing term used to denote the price of 1,000 advertisement impressions on one webpage. If a website publisher charges \$2.00 CPM that means an advertiser must pay \$2.00 for every 1000 impressions of its ad.

# %%
advertiser['CPM'] = (advertiser['cost']/advertiser['num_impressions'])

# %% [markdown]
# # eCPC
# eCPC is effective cost per click in online advertising.
#
# While CPC is the actual price for each click when buying clicks, eCPC is a calculated metric that tells you what the CPC would have been if you bought clicks instead of impressions, actions etc.
#
# The term CPC is often used instead of eCPC in the everyday language.
#
# # CPC
# CPC is the Cost per click when buying CPC.
#
# See the definition of a click.
#
# When buying CPC from an ad network, the network usually converts the CPC bid to CPM (or RPM) in the background, via the historical or predicted Click-through rate, so the network can optimize their CPM. The ad networks inventory is after all ad impressions, which they want to get most out of.
#
# In order to get a relatively high volume of ad impressions when buying CPC you need to make sure the ads is relevant and inviting to be clicked on. Low click-trough rates will make the ad network anticipate a low CPM for your campaign, which in turn gives the ad network a low revenue per impression, and they are likely to prioritize other competing campaigns.

# %%
advertiser['eCPC'] = (advertiser['cost']/advertiser['num_clicks'])/1000
advertiser
# Out:
#             num_impressions  num_clicks      cost       CTR        CPM  \
# advertiser
# 1458                 492353         385  33732036  0.078196  68.511893
# 2259                 133673          43  12411390  0.032168  92.848892
# 2261                 110122          36   9857123  0.032691  89.510933
# 2821                 211366         131  18799210  0.061978  88.941504
# 2997                  49829         217   3126220  0.435489  62.738967
# 3358                 264956         202  22308705  0.076239  84.197772
# 3386                 455041         320  34736523  0.070323  76.337128
# 3427                 402806         272  30386516  0.067526  75.437099
# 3476                 310835         187  23878311  0.060161  76.819892
#
#                   eCPC
# advertiser
# 1458         87.615678
# 2259        288.636977
# 2261        273.808972
# 2821        143.505420
# 2997         14.406544
# 3358        110.439134
# 3386        108.551634
# 3427        111.715132
# ...

# %%
# find number of impressions by advertiser
def get_variables_by_categorical(df, categorical):
    groupby_list = ['advertiser', categorical]
    advertiser = df.groupby(groupby_list)
    advertiser['num_impressions'] = df.groupby(groupby_list)['click'].count()
    advertiser['num_clicks'] = df.groupby(groupby_list)['click']#.sum()
    advertiser['cost_total'] = df.groupby(groupby_list)['payprice']#.sum()
    def click_cost(df):
        return df.loc[df['click'] == 1, 'payprice'].sum()
    advertiser['cost_click'] = df.groupby(groupby_list).apply(click_cost)
    advertiser['eCPC'] = (advertiser['cost']/advertiser['num_clicks'])
    advertiser['CPM'] = (advertiser['cost']/advertiser['num_impressions'])
    advertiser['CTR'] = (advertiser['num_clicks']/advertiser['num_impressions'])*100
    return advertiser.reset_index()

adv = get_variables_by_categorical(df, 'weekday')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-8a984c4ad2d9> in <module>()
#      14     return advertiser.reset_index()
#      15
# ---> 16 adv = get_variables_by_categorical(df, 'weekday')
#
# <ipython-input-114-8a984c4ad2d9> in get_variables_by_categorical(df, categorical)
#       3     groupby_list = ['advertiser', categorical]
#       4     advertiser = df.groupby(groupby_list)
# ----> 5     advertiser['num_impressions'] = df.groupby(groupby_list)['click'].count()
#       6     advertiser['num_clicks'] = df.groupby(groupby_list)['click']#.sum()
#       7     advertiser['cost_total'] = df.groupby(groupby_list)['payprice']#.sum()
#
# TypeError: 'DataFrameGroupBy' object does not support item assignment

# %%
df['advertiser'].unique()
# Out:
# array([3427, 2821, 1458, 2259, 3386, 3358, 3476, 2261, 2997])

# %%
def get_variables_by_categorical(df, categorical):
    groupby_list = ['advertiser', categorical]
    advertiser = df.set_index(groupby_list)
    advertiser['num_impressions'] = df.groupby(groupby_list)['click'].count()
    advertiser['num_clicks'] = df.groupby(groupby_list)['click'].sum()
    advertiser['cost'] = df.groupby(groupby_list)['payprice'].sum()
    def click_cost(df):
        return df.loc[df['click'] == 1, 'payprice'].sum()
    #advertiser['cost_click'] = df.groupby(groupby_list).apply(click_cost)
    advertiser['eCPC'] = (advertiser['cost']/advertiser['num_clicks'])/1000
    advertiser['CPM'] = (advertiser['cost']/advertiser['num_impressions'])
    advertiser['CTR'] = (advertiser['num_clicks']/advertiser['num_impressions'])*100
    return advertiser.reset_index()

def plot_categorical(x, y, advertisers, data, join=True):
    fig, ax = plt.subplots(1, 1, figsize=(12, 12))
    sns.pointplot(x=x, y=y, hue="advertiser", data=data[data['advertiser'].isin(advertisers)], ax=ax, join=join)
    return fig, ax

def plot_factor(x, y, advertisers, data):
    fig, ax = plt.subplots(1, 1, figsize=(12, 12))
    sns.factorplot(x=x, y=y, hue="advertiser", data=data[data['advertiser'].isin(advertisers)], ax=ax, kind='bar')
    return fig, ax

def plot_bar(x, y, advertisers, data):
    fig, ax = plt.subplots(1, 1, figsize=(12, 12))
    sns.barplot(x=x, y=y, hue="advertiser", data=data[data['advertiser'].isin(advertisers)], ax=ax)
    return fig, ax

# %%
df.columns
# Out:
# Index(['click', 'weekday', 'hour', 'bidid', 'userid', 'useragent', 'IP',
#        'region', 'city', 'adexchange', 'domain', 'url', 'urlid', 'slotid',
#        'slotwidth', 'slotheight', 'slotvisibility', 'slotformat', 'slotprice',
#        'creative', 'bidprice', 'payprice', 'keypage', 'advertiser', 'usertag'],
#       dtype='object')

# %%
ordinal_list = ['weekday', 'hour']
categorical_list = ['slotvisibility', 'slotformat', 'region']

target_list = ['CTR', 'eCPC', 'payprice']

# %%
df.groupby('advertiser')['click'].sum().sort_values()
# Out:
# advertiser
# 2261     36
# 2259     43
# 2821    131
# 3476    187
# 3358    202
# 2997    217
# 3427    272
# 3386    320
# 1458    385
# Name: click, dtype: int64

# %%
active_advertiser = [1458, 3386]

# %% [markdown]
# ## Plot all possible combinations

# %% [markdown]
# ### CTR

# %%
target = 'CTR'

# %%
ordinal = ordinal_list[0]
adv = get_variables_by_categorical(df, ordinal)
plot_categorical(x=ordinal, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x164091828>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12e2d2128>)

# %%
ordinal = ordinal_list[1]
adv = get_variables_by_categorical(df, ordinal)
plot_categorical(x=ordinal, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x164046080>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12e2d2c50>)

# %%
categorical = categorical_list[0]
adv = get_variables_by_categorical(df, categorical)
plot_bar(x=categorical, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1a5153160>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d5e22a90>)

# %%
categorical = categorical_list[1]
adv = get_variables_by_categorical(df, categorical)
plot_bar(x=categorical, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1d7616390>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d80df7f0>)

# %% [markdown]
# ### eCPC

# %%
target = 'eCPC'

# %%
ordinal = ordinal_list[0]
adv = get_variables_by_categorical(df, ordinal)
plot_categorical(x=ordinal, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x164250278>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d55fe3c8>)

# %%
ordinal = ordinal_list[1]
adv = get_variables_by_categorical(df, ordinal)
plot_categorical(x=ordinal, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1d80cdb00>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d63964e0>)

# %%
categorical = categorical_list[0]
adv = get_variables_by_categorical(df, categorical)
plot_bar(x=categorical, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1d64e25f8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d6791908>)

# %%
categorical = categorical_list[1]
adv = get_variables_by_categorical(df, categorical)
plot_bar(x=categorical, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1d6771d68>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d651f860>)

# %% [markdown]
# ### Payprice

# %%
target = 'payprice'

# %%
ordinal = ordinal_list[0]
adv = get_variables_by_categorical(df, ordinal)
plot_categorical(x=ordinal, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1d56c01d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d4a11c50>)

# %%
ordinal = ordinal_list[1]
adv = get_variables_by_categorical(df, ordinal)
plot_categorical(x=ordinal, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1f6f9b4e0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1f700c160>)

# %%
categorical = categorical_list[0]
adv = get_variables_by_categorical(df, categorical)
plot_bar(x=categorical, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1d4d23780>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d628fc18>)

# %%
categorical = categorical_list[1]
adv = get_variables_by_categorical(df, categorical)
plot_bar(x=categorical, y=target, advertisers=active_advertiser, data=adv)
# Out:
# (<matplotlib.figure.Figure at 0x1d4840588>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d486cc88>)
